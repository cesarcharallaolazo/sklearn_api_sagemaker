# %% [markdown]
# ## SETUP SAGEMAKER

# %%
bucket
# Out:
# 'sagemaker-us-east-1-428881646170'

# %%
import sagemaker
from sagemaker import get_execution_role

sagemaker_session = sagemaker.Session()

# Get a SageMaker-compatible role used by this Notebook Instance.
role = get_execution_role()

# S3 prefix
bucket = sagemaker_session.default_bucket()
prefix = "Scikit-LinearLearner-pipeline-abalone-example"

# %% [markdown]
# ## PREPROCESSING

# %% [markdown]
# #### Get Dataset

# %%
# !wget --directory-prefix=./abalone_data https://s3-us-west-2.amazonaws.com/sparkml-mleap/data/abalone/abalone.csv
# Out:
# --2021-08-05 17:25:04--  https://s3-us-west-2.amazonaws.com/sparkml-mleap/data/abalone/abalone.csv
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.218.218.0
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.218.218.0|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 191873 (187K) [binary/octet-stream]
# Saving to: ‘./abalone_data/abalone.csv’
#
# abalone.csv         100%[===================>] 187.38K   998KB/s    in 0.2s
#
# 2021-08-05 17:25:05 (998 KB/s) - ‘./abalone_data/abalone.csv’ saved [191873/191873]

# %%
# !ls
# Out:
# abalone_data  Abalone_example.ipynb  lost+found

# %% [markdown]
# #### Upload the data for training

# %%
WORK_DIRECTORY = "abalone_data"

train_input = sagemaker_session.upload_data(
    path="{}/{}".format(WORK_DIRECTORY, "abalone.csv"),
    bucket=bucket,
    key_prefix="{}/{}".format(prefix, "train"),
)

# %% [markdown]
# #### create script: sklearn_abalone_featurizer.py

# %% [markdown]
# ## Create SageMaker Scikit Preprocessor

# %%
from sagemaker.sklearn.estimator import SKLearn

FRAMEWORK_VERSION = "0.23-1"
script_path = "sklearn_abalone_featurizer.py"

sklearn_preprocessor = SKLearn(
    entry_point=script_path,
    role=role,
    framework_version=FRAMEWORK_VERSION,
    instance_type="ml.c4.xlarge",
    sagemaker_session=sagemaker_session,
)

# %%
sklearn_preprocessor.fit({"train": train_input})
# Out:
# 2021-08-05 17:45:23 Starting - Starting the training job...
# 2021-08-05 17:45:48 Starting - Launching requested ML instancesProfilerReport-1628185522: InProgress
# ......
# 2021-08-05 17:46:48 Starting - Preparing the instances for training......
# 2021-08-05 17:47:50 Downloading - Downloading input data...
# 2021-08-05 17:48:08 Training - Downloading the training image..2021-08-05 17:48:34,530 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2021-08-05 17:48:34,533 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-08-05 17:48:34,542 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2021-08-05 17:48:34,931 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-08-05 17:48:34,943 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-08-05 17:48:34,955 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-08-05 17:48:34,964 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {},
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-scikit-learn-2021-08-05-17-45-22-780",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-428881646170/sagemaker-scikit-learn-2021-08-05-17-45-22-780/source/sourcedir.tar.gz",
#     "module_name": "sklearn_abalone_featurizer",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "sklearn_abalone_featurizer.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={}
# SM_USER_ENTRY_POINT=sklearn_abalone_featurizer.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=sklearn_abalone_featurizer
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-428881646170/sagemaker-scikit-learn-2021-08-05-17-45-22-780/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-scikit-learn-2021-08-05-17-45-22-780","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-428881646170/sagemaker-scikit-learn-2021-08-05-17-45-22-780/source/sourcedir.tar.gz","module_name":"sklearn_abalone_featurizer","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"sklearn_abalone_featurizer.py"}
# SM_USER_ARGS=[]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python sklearn_abalone_featurizer.py
#
#
# saved model!
# 2021-08-05 17:48:36,936 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2021-08-05 17:48:49 Uploading - Uploading generated training model
# 2021-08-05 17:48:49 Completed - Training job completed
# Training seconds: 58
# Billable seconds: 58

# %% [markdown]
# ### Batch transform Job for our training data

# %%
transformer = sklearn_preprocessor.transformer(
    instance_count=1, instance_type="ml.c4.xlarge", assemble_with="Line", accept="text/csv"
)

# %%
transformer.transform(train_input, content_type="text/csv")
print("Waiting for transform job: " + transformer.latest_transform_job.job_name)
transformer.wait()
preprocessed_train = transformer.output_path
# Out:
# ..................................2021-08-05 18:06:01,093 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-08-05 18:06:01,093 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-08-05 18:06:01,096 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-08-05 18:06:01,096 INFO - sagemaker-containers - nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
#
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#
#     keepalive_timeout 3;
#
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#
#     location / {
#       return 404 "{}";
#     }
#
#   }
# }
#
#
# 2021-08-05 18:06:01,228 INFO - sagemaker-containers - Module sklearn_abalone_featurizer does not provide a setup.py.
# Generating setup.py
# 2021-08-05 18:06:01,228 INFO - sagemaker-containers - Generating setup.cfg
# 2021-08-05 18:06:01,096 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-08-05 18:06:01,096 INFO - sagemaker-containers - nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
#
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#
#     keepalive_timeout 3;
#
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#
#     location / {
#       return 404 "{}";
#     }
#
#   }
# }
#
#
# 2021-08-05 18:06:01,228 INFO - sagemaker-containers - Module sklearn_abalone_featurizer does not provide a setup.py.
# Generating setup.py
# 2021-08-05 18:06:01,228 INFO - sagemaker-containers - Generating setup.cfg
# 2021-08-05 18:06:01,229 INFO - sagemaker-containers - Generating MANIFEST.in
# 2021-08-05 18:06:01,229 INFO - sagemaker-containers - Installing module with the following command:
# /miniconda3/bin/python -m pip install .
# Processing /opt/ml/code
# Building wheels for collected packages: sklearn-abalone-featurizer
#   Building wheel for sklearn-abalone-featurizer (setup.py): started
#   Building wheel for sklearn-abalone-featurizer (setup.py): finished with status 'done'
#   Created wheel for sklearn-abalone-featurizer: filename=sklearn_abalone_featurizer-1.0.0-py2.py3-none-any.whl size=8315 sha256=11555e0b26136f077391386789441d605c1c9d50550e784f53016de1bf78212e
#   Stored in directory: /home/model-server/tmp/pip-ephem-wheel-cache-pqv3tj7r/wheels/3e/0f/51/2f1df833dd0412c1bc2f5ee56baac195b5be563353d111dca6
# Successfully built sklearn-abalone-featurizer
# Installing collected packages: sklearn-abalone-featurizer
# Successfully installed sklearn-abalone-featurizer-1.0.0
# [2021-08-05 18:06:03 +0000] [36] [INFO] Starting gunicorn 20.0.4
# [2021-08-05 18:06:03 +0000] [36] [INFO] Listening at: unix:/tmp/gunicorn.sock (36)
# [2021-08-05 18:06:03 +0000] [36] [INFO] Using worker: gevent
# [2021-08-05 18:06:03 +0000] [39] [INFO] Booting worker with pid: 39
# [2021-08-05 18:06:03 +0000] [40] [INFO] Booting worker with pid: 40
# [2021-08-05 18:06:03 +0000] [41] [INFO] Booting worker with pid: 41
# [2021-08-05 18:06:03 +0000] [48] [INFO] Booting worker with pid: 48
# 2021-08-05 18:06:01,229 INFO - sagemaker-containers - Generating MANIFEST.in
# 2021-08-05 18:06:01,229 INFO - sagemaker-containers - Installing module with the following command:
# /miniconda3/bin/python -m pip install .
# Processing /opt/ml/code
# Building wheels for collected packages: sklearn-abalone-featurizer
#   Building wheel for sklearn-abalone-featurizer (setup.py): started
#   Building wheel for sklearn-abalone-featurizer (setup.py): finished with status 'done'
#   Created wheel for sklearn-abalone-featurizer: filename=sklearn_abalone_featurizer-1.0.0-py2.py3-none-any.whl size=8315 sha256=11555e0b26136f077391386789441d605c1c9d50550e784f53016de1bf78212e
#   Stored in directory: /home/model-server/tmp/pip-ephem-wheel-cache-pqv3tj7r/wheels/3e/0f/51/2f1df833dd0412c1bc2f5ee56baac195b5be563353d111dca6
# Successfully built sklearn-abalone-featurizer
# Installing collected packages: sklearn-abalone-featurizer
# Successfully installed sklearn-abalone-featurizer-1.0.0
# [2021-08-05 18:06:03 +0000] [36] [INFO] Starting gunicorn 20.0.4
# [2021-08-05 18:06:03 +0000] [36] [INFO] Listening at: unix:/tmp/gunicorn.sock (36)
# [2021-08-05 18:06:03 +0000] [36] [INFO] Using worker: gevent
# [2021-08-05 18:06:03 +0000] [39] [INFO] Booting worker with pid: 39
# [2021-08-05 18:06:03 +0000] [40] [INFO] Booting worker with pid: 40
# [2021-08-05 18:06:03 +0000] [41] [INFO] Booting worker with pid: 41
# [2021-08-05 18:06:03 +0000] [48] [INFO] Booting worker with pid: 48
# 2021-08-05 18:06:06,754 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [05/Aug/2021:18:06:07 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [05/Aug/2021:18:06:07 +0000] "GET /execution-parameters HTTP/1.1" 404 232 "-" "Go-http-client/1.1"
# 2021-08-05 18:06:06,754 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [05/Aug/2021:18:06:07 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [05/Aug/2021:18:06:07 +0000] "GET /execution-parameters HTTP/1.1" 404 232 "-" "Go-http-client/1.1"
# 2021-08-05 18:06:07,363 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# /miniconda3/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2021-08-05 18:06:07,363 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# /miniconda3/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 169.254.255.130 - - [05/Aug/2021:18:06:07 +0000] "POST /invocations HTTP/1.1" 200 641942 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [05/Aug/2021:18:06:07 +0000] "POST /invocations HTTP/1.1" 200 641942 "-" "Go-http-client/1.1"
# 2021-08-05T18:06:07.319:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
#
# Waiting for transform job: sagemaker-scikit-learn-2021-08-05-18-00-36-214
# 2021-08-05 18:06:01,093 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-08-05 18:06:01,093 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-08-05 18:06:01,096 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-08-05 18:06:01,096 INFO - sagemaker-containers - nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
#
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#
#     keepalive_timeout 3;
#
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#
#     location / {
#       return 404 "{}";
#     }
#
#   }
# }
#
#
# 2021-08-05 18:06:01,228 INFO - sagemaker-containers - Module sklearn_abalone_featurizer does not provide a setup.py.
# Generating setup.py
# 2021-08-05 18:06:01,228 INFO - sagemaker-containers - Generating setup.cfg
# 2021-08-05 18:06:01,096 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-08-05 18:06:01,096 INFO - sagemaker-containers - nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
#
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#
#     keepalive_timeout 3;
#
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#
#     location / {
#       return 404 "{}";
#     }
#
#   }
# }
#
#
# 2021-08-05 18:06:01,228 INFO - sagemaker-containers - Module sklearn_abalone_featurizer does not provide a setup.py.
# Generating setup.py
# 2021-08-05 18:06:01,228 INFO - sagemaker-containers - Generating setup.cfg
# 2021-08-05 18:06:01,229 INFO - sagemaker-containers - Generating MANIFEST.in
# 2021-08-05 18:06:01,229 INFO - sagemaker-containers - Installing module with the following command:
# /miniconda3/bin/python -m pip install .
# Processing /opt/ml/code
# Building wheels for collected packages: sklearn-abalone-featurizer
#   Building wheel for sklearn-abalone-featurizer (setup.py): started
#   Building wheel for sklearn-abalone-featurizer (setup.py): finished with status 'done'
#   Created wheel for sklearn-abalone-featurizer: filename=sklearn_abalone_featurizer-1.0.0-py2.py3-none-any.whl size=8315 sha256=11555e0b26136f077391386789441d605c1c9d50550e784f53016de1bf78212e
#   Stored in directory: /home/model-server/tmp/pip-ephem-wheel-cache-pqv3tj7r/wheels/3e/0f/51/2f1df833dd0412c1bc2f5ee56baac195b5be563353d111dca6
# Successfully built sklearn-abalone-featurizer
# Installing collected packages: sklearn-abalone-featurizer
# Successfully installed sklearn-abalone-featurizer-1.0.0
# [2021-08-05 18:06:03 +0000] [36] [INFO] Starting gunicorn 20.0.4
# [2021-08-05 18:06:03 +0000] [36] [INFO] Listening at: unix:/tmp/gunicorn.sock (36)
# [2021-08-05 18:06:03 +0000] [36] [INFO] Using worker: gevent
# [2021-08-05 18:06:03 +0000] [39] [INFO] Booting worker with pid: 39
# [2021-08-05 18:06:03 +0000] [40] [INFO] Booting worker with pid: 40
# [2021-08-05 18:06:03 +0000] [41] [INFO] Booting worker with pid: 41
# [2021-08-05 18:06:03 +0000] [48] [INFO] Booting worker with pid: 48
# 2021-08-05 18:06:01,229 INFO - sagemaker-containers - Generating MANIFEST.in
# 2021-08-05 18:06:01,229 INFO - sagemaker-containers - Installing module with the following command:
# /miniconda3/bin/python -m pip install .
# Processing /opt/ml/code
# Building wheels for collected packages: sklearn-abalone-featurizer
#   Building wheel for sklearn-abalone-featurizer (setup.py): started
#   Building wheel for sklearn-abalone-featurizer (setup.py): finished with status 'done'
#   Created wheel for sklearn-abalone-featurizer: filename=sklearn_abalone_featurizer-1.0.0-py2.py3-none-any.whl size=8315 sha256=11555e0b26136f077391386789441d605c1c9d50550e784f53016de1bf78212e
#   Stored in directory: /home/model-server/tmp/pip-ephem-wheel-cache-pqv3tj7r/wheels/3e/0f/51/2f1df833dd0412c1bc2f5ee56baac195b5be563353d111dca6
# Successfully built sklearn-abalone-featurizer
# Installing collected packages: sklearn-abalone-featurizer
# Successfully installed sklearn-abalone-featurizer-1.0.0
# [2021-08-05 18:06:03 +0000] [36] [INFO] Starting gunicorn 20.0.4
# [2021-08-05 18:06:03 +0000] [36] [INFO] Listening at: unix:/tmp/gunicorn.sock (36)
# [2021-08-05 18:06:03 +0000] [36] [INFO] Using worker: gevent
# [2021-08-05 18:06:03 +0000] [39] [INFO] Booting worker with pid: 39
# [2021-08-05 18:06:03 +0000] [40] [INFO] Booting worker with pid: 40
# [2021-08-05 18:06:03 +0000] [41] [INFO] Booting worker with pid: 41
# [2021-08-05 18:06:03 +0000] [48] [INFO] Booting worker with pid: 48
# 2021-08-05 18:06:06,754 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [05/Aug/2021:18:06:07 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [05/Aug/2021:18:06:07 +0000] "GET /execution-parameters HTTP/1.1" 404 232 "-" "Go-http-client/1.1"
# 2021-08-05 18:06:06,754 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [05/Aug/2021:18:06:07 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [05/Aug/2021:18:06:07 +0000] "GET /execution-parameters HTTP/1.1" 404 232 "-" "Go-http-client/1.1"
# 2021-08-05 18:06:07,363 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# /miniconda3/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2021-08-05 18:06:07,363 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# /miniconda3/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 169.254.255.130 - - [05/Aug/2021:18:06:07 +0000] "POST /invocations HTTP/1.1" 200 641942 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [05/Aug/2021:18:06:07 +0000] "POST /invocations HTTP/1.1" 200 641942 "-" "Go-http-client/1.1"
# 2021-08-05T18:06:07.319:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD

# %%
preprocessed_train
# Out:
# 's3://sagemaker-us-east-1-428881646170/sagemaker-scikit-learn-2021-08-05-18-00-36-214'

# %% [markdown]
# ## Fit a LinearLearner Model with the preprocessed data

# %%
import boto3
from sagemaker.image_uris import retrieve

ll_image = retrieve("linear-learner", boto3.Session().region_name)

# %%
ll_image
# Out:
# '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner:1'

# %%
s3_ll_output_key_prefix = "ll_training_output"
s3_ll_output_location = "s3://{}/{}/{}/{}".format(
    bucket, prefix, s3_ll_output_key_prefix, "ll_model"
)

ll_estimator = sagemaker.estimator.Estimator(
    ll_image,
    role,
    instance_count=1,
    instance_type="ml.m4.2xlarge",
    volume_size=20,
    max_run=3600,
    input_mode="File",
    output_path=s3_ll_output_location,
    sagemaker_session=sagemaker_session,
)

ll_estimator.set_hyperparameters(feature_dim=10, predictor_type="regressor", mini_batch_size=32)

ll_train_data = sagemaker.inputs.TrainingInput(
    preprocessed_train,
    distribution="FullyReplicated",
    content_type="text/csv",
    s3_data_type="S3Prefix",
)

data_channels = {"train": ll_train_data}
ll_estimator.fit(inputs=data_channels, logs=True)
# Out:
# 2021-08-05 18:19:29 Starting - Starting the training job...
# 2021-08-05 18:19:52 Starting - Launching requested ML instancesProfilerReport-1628187568: InProgress
# ...
# 2021-08-05 18:20:25 Starting - Preparing the instances for training.........
# 2021-08-05 18:21:57 Downloading - Downloading input data.........
# 2021-08-05 18:23:17 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [08/05/2021 18:23:42 INFO 140223054878528] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [08/05/2021 18:23:42 INFO 140223054878528] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '10', 'predictor_type': 'regressor', 'mini_batch_size': '32'}
# [08/05/2021 18:23:42 INFO 140223054878528] Final configuration: {'mini_batch_size': '32', 'epochs': '15', 'feature_dim': '10', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [08/05/2021 18:23:42 WARNING 140223054878528] Loggers have already been setup.
# Process 1 is a worker.
# [08/05/2021 18:23:42 INFO 140223054878528] Using default worker.
# [08/05/2021 18:23:42 INFO 140223054878528] Checkpoint loading and saving are disabled.
# [08/05/2021 18:23:42 INFO 140223054878528] Create Store: local
# [08/05/2021 18:23:44 INFO 140223054878528] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f87dc726410>
# [08/05/2021 18:23:44 INFO 140223054878528] Scaling model computed with parameters:
#  {'stdev_label':
# [3.2286305]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [1.0008886  1.0007695  1.000614   1.0006257  1.0004948  1.000646
#  1.0008249  0.46370658 0.46710348 0.4815376 ]
# <NDArray 10 @cpu(0)>, 'mean_label':
# [9.9362955]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [-8.43582675e-05  1.30765256e-04  1.02182385e-05  2.60140863e-04
#  -6.14598393e-05  1.63597404e-04  6.73765666e-04  3.12980711e-01
#   3.21634650e-01  3.65384579e-01]
# <NDArray 10 @cpu(0)>}
# [08/05/2021 18:23:44 INFO 140223054878528] nvidia-smi: took 0.031 seconds to run.
# [08/05/2021 18:23:44 INFO 140223054878528] nvidia-smi identified 0 GPUs.
# [08/05/2021 18:23:44 INFO 140223054878528] Number of GPUs being used: 0
# #metrics {"StartTime": 1628187824.1525407, "EndTime": 1628187824.1525822, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 4209.0, "count": 1, "min": 4209, "max": 4209}, "Total Batches Seen": {"sum": 132.0, "count": 1, "min": 132, "max": 132}, "Max Records Seen Between Resets": {"sum": 4177.0, "count": 1, "min": 4177, "max": 4177}, "Max Batches Seen Between Resets": {"sum": 131.0, "count": 1, "min": 131, "max": 131}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
#
# 2021-08-05 18:23:53 Training - Training image download completed. Training in progress.#metrics {"StartTime": 1628187827.4399145, "EndTime": 1628187827.4399724, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.8006998809484335, "count": 1, "min": 0.8006998809484335, "max": 0.8006998809484335}}}
#
# #metrics {"StartTime": 1628187827.4400568, "EndTime": 1628187827.4400713, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.7895347111500226, "count": 1, "min": 0.7895347111500226, "max": 0.7895347111500226}}}
#
# #metrics {"StartTime": 1628187827.4401274, "EndTime": 1628187827.4401445, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.8145967419330891, "count": 1, "min": 0.8145967419330891, "max": 0.8145967419330891}}}
#
# #metrics {"StartTime": 1628187827.4402053, "EndTime": 1628187827.440221, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.8084366976641691, "count": 1, "min": 0.8084366976641691, "max": 0.8084366976641691}}}
#
# #metrics {"StartTime": 1628187827.44028, "EndTime": 1628187827.4402978, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 1.0467860493522423, "count": 1, "min": 1.0467860493522423, "max": 1.0467860493522423}}}
#
# #metrics {"StartTime": 1628187827.4403548, "EndTime": 1628187827.440371, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 1.0041040941499746, "count": 1, "min": 1.0041040941499746, "max": 1.0041040941499746}}}
#
# #metrics {"StartTime": 1628187827.4404252, "EndTime": 1628187827.4404418, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 1.0218667515768454, "count": 1, "min": 1.0218667515768454, "max": 1.0218667515768454}}}
#
# #metrics {"StartTime": 1628187827.4404962, "EndTime": 1628187827.4405122, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 1.079760283117111, "count": 1, "min": 1.079760283117111, "max": 1.079760283117111}}}
#
# #metrics {"StartTime": 1628187827.4405677, "EndTime": 1628187827.4405837, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.7791787115427163, "count": 1, "min": 0.7791787115427163, "max": 0.7791787115427163}}}
#
# #metrics {"StartTime": 1628187827.4406474, "EndTime": 1628187827.4406648, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.7981268129669703, "count": 1, "min": 0.7981268129669703, "max": 0.7981268129669703}}}
#
# #metrics {"StartTime": 1628187827.4407222, "EndTime": 1628187827.440738, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.8037968301142637, "count": 1, "min": 0.8037968301142637, "max": 0.8037968301142637}}}
#
# #metrics {"StartTime": 1628187827.4408019, "EndTime": 1628187827.4408195, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.7818732198614341, "count": 1, "min": 0.7818732198614341, "max": 0.7818732198614341}}}
#
# #metrics {"StartTime": 1628187827.4408817, "EndTime": 1628187827.4408987, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 1.0660263233459912, "count": 1, "min": 1.0660263233459912, "max": 1.0660263233459912}}}
#
# #metrics {"StartTime": 1628187827.4409611, "EndTime": 1628187827.4409773, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.9897483714498007, "count": 1, "min": 0.9897483714498007, "max": 0.9897483714498007}}}
#
# #metrics {"StartTime": 1628187827.4410412, "EndTime": 1628187827.4410586, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 1.0237144654759993, "count": 1, "min": 1.0237144654759993, "max": 1.0237144654759993}}}
#
# #metrics {"StartTime": 1628187827.4411178, "EndTime": 1628187827.441131, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 1.0417333419506367, "count": 1, "min": 1.0417333419506367, "max": 1.0417333419506367}}}
#
# #metrics {"StartTime": 1628187827.4411924, "EndTime": 1628187827.4412103, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.7922092190728738, "count": 1, "min": 0.7922092190728738, "max": 0.7922092190728738}}}
#
# #metrics {"StartTime": 1628187827.441273, "EndTime": 1628187827.4412897, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.819162551428263, "count": 1, "min": 0.819162551428263, "max": 0.819162551428263}}}
#
# #metrics {"StartTime": 1628187827.4413526, "EndTime": 1628187827.4413688, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.8102903077808711, "count": 1, "min": 0.8102903077808711, "max": 0.8102903077808711}}}
#
# #metrics {"StartTime": 1628187827.4414322, "EndTime": 1628187827.4414487, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.8241688800545839, "count": 1, "min": 0.8241688800545839, "max": 0.8241688800545839}}}
#
# #metrics {"StartTime": 1628187827.4415123, "EndTime": 1628187827.4415295, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.9851125761866569, "count": 1, "min": 0.9851125761866569, "max": 0.9851125761866569}}}
#
# #metrics {"StartTime": 1628187827.4415903, "EndTime": 1628187827.4416068, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.9940450415015221, "count": 1, "min": 0.9940450415015221, "max": 0.9940450415015221}}}
#
# #metrics {"StartTime": 1628187827.4416666, "EndTime": 1628187827.441683, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 1.0119663345699126, "count": 1, "min": 1.0119663345699126, "max": 1.0119663345699126}}}
#
# #metrics {"StartTime": 1628187827.441727, "EndTime": 1628187827.4417367, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.9945380521508363, "count": 1, "min": 0.9945380521508363, "max": 0.9945380521508363}}}
#
# #metrics {"StartTime": 1628187827.4417658, "EndTime": 1628187827.4417741, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 1.0228771389103852, "count": 1, "min": 1.0228771389103852, "max": 1.0228771389103852}}}
#
# #metrics {"StartTime": 1628187827.4418018, "EndTime": 1628187827.4418097, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 1.026970586180687, "count": 1, "min": 1.026970586180687, "max": 1.026970586180687}}}
#
# #metrics {"StartTime": 1628187827.441837, "EndTime": 1628187827.441845, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 1.0334852979733393, "count": 1, "min": 1.0334852979733393, "max": 1.0334852979733393}}}
#
# #metrics {"StartTime": 1628187827.441871, "EndTime": 1628187827.4418786, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 1.0311863417235705, "count": 1, "min": 1.0311863417235705, "max": 1.0311863417235705}}}
#
# #metrics {"StartTime": 1628187827.4419045, "EndTime": 1628187827.4419127, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.2156264201379738, "count": 1, "min": 1.2156264201379738, "max": 1.2156264201379738}}}
#
# #metrics {"StartTime": 1628187827.441939, "EndTime": 1628187827.4419515, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.2209841376313797, "count": 1, "min": 1.2209841376313797, "max": 1.2209841376313797}}}
#
# #metrics {"StartTime": 1628187827.441996, "EndTime": 1628187827.442006, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.2138410201439491, "count": 1, "min": 1.2138410201439491, "max": 1.2138410201439491}}}
#
# #metrics {"StartTime": 1628187827.4420505, "EndTime": 1628187827.44206, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.2290772231152425, "count": 1, "min": 1.2290772231152425, "max": 1.2290772231152425}}}
#
# [08/05/2021 18:23:47 INFO 140223054878528] #quality_metric: host=algo-1, epoch=0, train mse_objective <loss>=0.8006998809484335
# [08/05/2021 18:23:47 INFO 140223054878528] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=mse_objective, value=0.7791787115427163
# [08/05/2021 18:23:47 INFO 140223054878528] Epoch 0: Loss improved. Updating best model
# [08/05/2021 18:23:47 INFO 140223054878528] Saving model for epoch: 0
# [08/05/2021 18:23:47 INFO 140223054878528] Saved checkpoint to "/tmp/tmpjka0jpym/mx-mod-0000.params"
# [08/05/2021 18:23:47 INFO 140223054878528] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1628187824.152882, "EndTime": 1628187827.4568396, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 8386.0, "count": 1, "min": 8386, "max": 8386}, "Total Batches Seen": {"sum": 263.0, "count": 1, "min": 263, "max": 263}, "Max Records Seen Between Resets": {"sum": 4177.0, "count": 1, "min": 4177, "max": 4177}, "Max Batches Seen Between Resets": {"sum": 131.0, "count": 1, "min": 131, "max": 131}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 4177.0, "count": 1, "min": 4177, "max": 4177}, "Number of Batches Since Last Reset": {"sum": 131.0, "count": 1, "min": 131, "max": 131}}}
#
# [08/05/2021 18:23:47 INFO 140223054878528] #throughput_metric: host=algo-1, train throughput=1264.1934732674822 records/second
# #metrics {"StartTime": 1628187831.1740577, "EndTime": 1628187831.1741185, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.7001721923167888, "count": 1, "min": 0.7001721923167888, "max": 0.7001721923167888}}}
#
# #metrics {"StartTime": 1628187831.1741998, "EndTime": 1628187831.1742136, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.6973208563259015, "count": 1, "min": 0.6973208563259015, "max": 0.6973208563259015}}}
#
# #metrics {"StartTime": 1628187831.1742475, "EndTime": 1628187831.1742566, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.7065229558027708, "count": 1, "min": 0.7065229558027708, "max": 0.7065229558027708}}}
#
# #metrics {"StartTime": 1628187831.1742926, "EndTime": 1628187831.1743028, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.703621689373484, "count": 1, "min": 0.703621689373484, "max": 0.703621689373484}}}
#
# #metrics {"StartTime": 1628187831.1743586, "EndTime": 1628187831.1743696, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.8627396203004397, "count": 1, "min": 0.8627396203004397, "max": 0.8627396203004397}}}
#
# #metrics {"StartTime": 1628187831.1744173, "EndTime": 1628187831.1744304, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 1.1793146948401745, "count": 1, "min": 1.1793146948401745, "max": 1.1793146948401745}}}
#
# #metrics {"StartTime": 1628187831.174489, "EndTime": 1628187831.1745055, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.874474240724857, "count": 1, "min": 0.874474240724857, "max": 0.874474240724857}}}
#
# #metrics {"StartTime": 1628187831.1745636, "EndTime": 1628187831.1745796, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 1.0559686912940098, "count": 1, "min": 1.0559686912940098, "max": 1.0559686912940098}}}
#
# #metrics {"StartTime": 1628187831.1746418, "EndTime": 1628187831.1746597, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.6838880081016284, "count": 1, "min": 0.6838880081016284, "max": 0.6838880081016284}}}
#
# #metrics {"StartTime": 1628187831.174713, "EndTime": 1628187831.1747284, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.7048241012371503, "count": 1, "min": 0.7048241012371503, "max": 0.7048241012371503}}}
#
# #metrics {"StartTime": 1628187831.1747875, "EndTime": 1628187831.174839, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.6981234580851519, "count": 1, "min": 0.6981234580851519, "max": 0.6981234580851519}}}
#
# #metrics {"StartTime": 1628187831.1748817, "EndTime": 1628187831.174894, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.6940391752009208, "count": 1, "min": 0.6940391752009208, "max": 0.6940391752009208}}}
#
# #metrics {"StartTime": 1628187831.174954, "EndTime": 1628187831.174966, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.8599198917929943, "count": 1, "min": 0.8599198917929943, "max": 0.8599198917929943}}}
#
# #metrics {"StartTime": 1628187831.175015, "EndTime": 1628187831.1750312, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 1.1895205556200101, "count": 1, "min": 1.1895205556200101, "max": 1.1895205556200101}}}
#
# #metrics {"StartTime": 1628187831.1750805, "EndTime": 1628187831.1750953, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.8808853080066351, "count": 1, "min": 0.8808853080066351, "max": 0.8808853080066351}}}
#
# #metrics {"StartTime": 1628187831.1751297, "EndTime": 1628187831.1751444, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 1.1158185453369067, "count": 1, "min": 1.1158185453369067, "max": 1.1158185453369067}}}
#
# #metrics {"StartTime": 1628187831.175206, "EndTime": 1628187831.1752222, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.7243069729552819, "count": 1, "min": 0.7243069729552819, "max": 0.7243069729552819}}}
#
# #metrics {"StartTime": 1628187831.1752703, "EndTime": 1628187831.1752863, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.741506131279927, "count": 1, "min": 0.741506131279927, "max": 0.741506131279927}}}
#
# #metrics {"StartTime": 1628187831.175343, "EndTime": 1628187831.175359, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.7274297984746786, "count": 1, "min": 0.7274297984746786, "max": 0.7274297984746786}}}
#
# #metrics {"StartTime": 1628187831.1754174, "EndTime": 1628187831.1754289, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.7442248525527807, "count": 1, "min": 0.7442248525527807, "max": 0.7442248525527807}}}
#
# #metrics {"StartTime": 1628187831.175478, "EndTime": 1628187831.175493, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.9909510791874849, "count": 1, "min": 0.9909510791874849, "max": 0.9909510791874849}}}
#
# #metrics {"StartTime": 1628187831.1755526, "EndTime": 1628187831.1755643, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 1.2699528419341033, "count": 1, "min": 1.2699528419341033, "max": 1.2699528419341033}}}
#
# #metrics {"StartTime": 1628187831.1756248, "EndTime": 1628187831.1756415, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.966528815174332, "count": 1, "min": 0.966528815174332, "max": 0.966528815174332}}}
#
# #metrics {"StartTime": 1628187831.1756997, "EndTime": 1628187831.1757164, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 1.279348279048617, "count": 1, "min": 1.279348279048617, "max": 1.279348279048617}}}
#
# #metrics {"StartTime": 1628187831.1757736, "EndTime": 1628187831.1757896, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 1.0220404353279333, "count": 1, "min": 1.0220404353279333, "max": 1.0220404353279333}}}
#
# #metrics {"StartTime": 1628187831.1758523, "EndTime": 1628187831.175869, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 1.030780710795751, "count": 1, "min": 1.030780710795751, "max": 1.030780710795751}}}
#
# #metrics {"StartTime": 1628187831.175925, "EndTime": 1628187831.175936, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 1.0219837889075278, "count": 1, "min": 1.0219837889075278, "max": 1.0219837889075278}}}
#
# #metrics {"StartTime": 1628187831.1759949, "EndTime": 1628187831.176011, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 1.030818541176044, "count": 1, "min": 1.030818541176044, "max": 1.030818541176044}}}
#
# #metrics {"StartTime": 1628187831.1760685, "EndTime": 1628187831.1760812, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.1457130735310224, "count": 1, "min": 1.1457130735310224, "max": 1.1457130735310224}}}
#
# #metrics {"StartTime": 1628187831.1761334, "EndTime": 1628187831.1761487, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.2532170024055702, "count": 1, "min": 1.2532170024055702, "max": 1.2532170024055702}}}
#
# #metrics {"StartTime": 1628187831.1762025, "EndTime": 1628187831.176218, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.1462875348444168, "count": 1, "min": 1.1462875348444168, "max": 1.1462875348444168}}}
#
# #metrics {"StartTime": 1628187831.1762772, "EndTime": 1628187831.1762936, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.25250958060989, "count": 1, "min": 1.25250958060989, "max": 1.25250958060989}}}
#
# [08/05/2021 18:23:51 INFO 140223054878528] #quality_metric: host=algo-1, epoch=1, train mse_objective <loss>=0.7001721923167888
# [08/05/2021 18:23:51 INFO 140223054878528] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=mse_objective, value=0.6838880081016284
# [08/05/2021 18:23:51 INFO 140223054878528] Epoch 1: Loss improved. Updating best model
# [08/05/2021 18:23:51 INFO 140223054878528] Saving model for epoch: 1
# [08/05/2021 18:23:51 INFO 140223054878528] Saved checkpoint to "/tmp/tmpde7aieyp/mx-mod-0000.params"
# [08/05/2021 18:23:51 INFO 140223054878528] #progress_metric: host=algo-1, completed 13.333333333333334 % of epochs
# #metrics {"StartTime": 1628187827.4571323, "EndTime": 1628187831.1864347, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 12563.0, "count": 1, "min": 12563, "max": 12563}, "Total Batches Seen": {"sum": 394.0, "count": 1, "min": 394, "max": 394}, "Max Records Seen Between Resets": {"sum": 4177.0, "count": 1, "min": 4177, "max": 4177}, "Max Batches Seen Between Resets": {"sum": 131.0, "count": 1, "min": 131, "max": 131}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 4177.0, "count": 1, "min": 4177, "max": 4177}, "Number of Batches Since Last Reset": {"sum": 131.0, "count": 1, "min": 131, "max": 131}}}
#
# [08/05/2021 18:23:51 INFO 140223054878528] #throughput_metric: host=algo-1, train throughput=1120.0013583516893 records/second
# #metrics {"StartTime": 1628187834.5889382, "EndTime": 1628187834.5889957, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.651952166798023, "count": 1, "min": 0.651952166798023, "max": 0.651952166798023}}}
#
# #metrics {"StartTime": 1628187834.5890756, "EndTime": 1628187834.589089, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.6520103012713102, "count": 1, "min": 0.6520103012713102, "max": 0.6520103012713102}}}
#
# #metrics {"StartTime": 1628187834.5891247, "EndTime": 1628187834.589134, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.65748851196124, "count": 1, "min": 0.65748851196124, "max": 0.65748851196124}}}
#
# #metrics {"StartTime": 1628187834.5891697, "EndTime": 1628187834.5891793, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.6544605829967902, "count": 1, "min": 0.6544605829967902, "max": 0.6544605829967902}}}
#
# #metrics {"StartTime": 1628187834.5892081, "EndTime": 1628187834.5892165, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.7881470860196994, "count": 1, "min": 0.7881470860196994, "max": 0.7881470860196994}}}
#
# #metrics {"StartTime": 1628187834.5892498, "EndTime": 1628187834.5892587, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.9661154467325944, "count": 1, "min": 0.9661154467325944, "max": 0.9661154467325944}}}
#
# #metrics {"StartTime": 1628187834.589291, "EndTime": 1628187834.5892992, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.7909685745835304, "count": 1, "min": 0.7909685745835304, "max": 0.7909685745835304}}}
#
# #metrics {"StartTime": 1628187834.5893254, "EndTime": 1628187834.5893333, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 1.001393732199302, "count": 1, "min": 1.001393732199302, "max": 1.001393732199302}}}
#
# #metrics {"StartTime": 1628187834.5893657, "EndTime": 1628187834.5893748, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.6404793813538093, "count": 1, "min": 0.6404793813538093, "max": 0.6404793813538093}}}
#
# #metrics {"StartTime": 1628187834.5894024, "EndTime": 1628187834.5894103, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.659976379859906, "count": 1, "min": 0.659976379859906, "max": 0.659976379859906}}}
#
# #metrics {"StartTime": 1628187834.5894358, "EndTime": 1628187834.5894437, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.65086231286136, "count": 1, "min": 0.65086231286136, "max": 0.65086231286136}}}
#
# #metrics {"StartTime": 1628187834.5894763, "EndTime": 1628187834.5894866, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.6505326246986023, "count": 1, "min": 0.6505326246986023, "max": 0.6505326246986023}}}
#
# #metrics {"StartTime": 1628187834.5895398, "EndTime": 1628187834.5895505, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.790616584282655, "count": 1, "min": 0.790616584282655, "max": 0.790616584282655}}}
#
# #metrics {"StartTime": 1628187834.589586, "EndTime": 1628187834.589595, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.9731382561417726, "count": 1, "min": 0.9731382561417726, "max": 0.9731382561417726}}}
#
# #metrics {"StartTime": 1628187834.5896232, "EndTime": 1628187834.5896313, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.7938793940612903, "count": 1, "min": 0.7938793940612903, "max": 0.7938793940612903}}}
#
# #metrics {"StartTime": 1628187834.5896678, "EndTime": 1628187834.589683, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.9947252224271114, "count": 1, "min": 0.9947252224271114, "max": 0.9947252224271114}}}
#
# #metrics {"StartTime": 1628187834.5897286, "EndTime": 1628187834.5897386, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.70907634261709, "count": 1, "min": 0.70907634261709, "max": 0.70907634261709}}}
#
# #metrics {"StartTime": 1628187834.5897665, "EndTime": 1628187834.5897744, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.730377668600816, "count": 1, "min": 0.730377668600816, "max": 0.730377668600816}}}
#
# #metrics {"StartTime": 1628187834.5897996, "EndTime": 1628187834.589807, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.7099492000845763, "count": 1, "min": 0.7099492000845763, "max": 0.7099492000845763}}}
#
# #metrics {"StartTime": 1628187834.589842, "EndTime": 1628187834.589857, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.7306849829852581, "count": 1, "min": 0.7306849829852581, "max": 0.7306849829852581}}}
#
# #metrics {"StartTime": 1628187834.5899029, "EndTime": 1628187834.589913, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.8529888512423405, "count": 1, "min": 0.8529888512423405, "max": 0.8529888512423405}}}
#
# #metrics {"StartTime": 1628187834.589941, "EndTime": 1628187834.589949, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 1.0501642117706629, "count": 1, "min": 1.0501642117706629, "max": 1.0501642117706629}}}
#
# #metrics {"StartTime": 1628187834.589976, "EndTime": 1628187834.58999, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.8520048572180363, "count": 1, "min": 0.8520048572180363, "max": 0.8520048572180363}}}
#
# #metrics {"StartTime": 1628187834.5900471, "EndTime": 1628187834.5900633, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 1.0455913403859505, "count": 1, "min": 1.0455913403859505, "max": 1.0455913403859505}}}
#
# #metrics {"StartTime": 1628187834.5901258, "EndTime": 1628187834.5901427, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 1.014952431504543, "count": 1, "min": 1.014952431504543, "max": 1.014952431504543}}}
#
# #metrics {"StartTime": 1628187834.590205, "EndTime": 1628187834.5902216, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 1.0303326720228563, "count": 1, "min": 1.0303326720228563, "max": 1.0303326720228563}}}
#
# #metrics {"StartTime": 1628187834.5902944, "EndTime": 1628187834.5903125, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 1.0150471660953302, "count": 1, "min": 1.0150471660953302, "max": 1.0150471660953302}}}
#
# #metrics {"StartTime": 1628187834.5903785, "EndTime": 1628187834.5903912, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 1.0303711272203004, "count": 1, "min": 1.0303711272203004, "max": 1.0303711272203004}}}
#
# #metrics {"StartTime": 1628187834.5904448, "EndTime": 1628187834.5904603, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.0912303805351258, "count": 1, "min": 1.0912303805351258, "max": 1.0912303805351258}}}
#
# #metrics {"StartTime": 1628187834.5905175, "EndTime": 1628187834.5905328, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.2371659375440616, "count": 1, "min": 1.2371659375440616, "max": 1.2371659375440616}}}
#
# #metrics {"StartTime": 1628187834.5905879, "EndTime": 1628187834.5906022, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.0911422190184776, "count": 1, "min": 1.0911422190184776, "max": 1.0911422190184776}}}
#
# #metrics {"StartTime": 1628187834.5906568, "EndTime": 1628187834.5906706, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.2366221335644905, "count": 1, "min": 1.2366221335644905, "max": 1.2366221335644905}}}
#
# [08/05/2021 18:23:54 INFO 140223054878528] #quality_metric: host=algo-1, epoch=2, train mse_objective <loss>=0.651952166798023
# [08/05/2021 18:23:54 INFO 140223054878528] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=mse_objective, value=0.6404793813538093
# [08/05/2021 18:23:54 INFO 140223054878528] Epoch 2: Loss improved. Updating best model
# [08/05/2021 18:23:54 INFO 140223054878528] Saving model for epoch: 2
# [08/05/2021 18:23:54 INFO 140223054878528] Saved checkpoint to "/tmp/tmpld7g0b6t/mx-mod-0000.params"
# [08/05/2021 18:23:54 INFO 140223054878528] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1628187831.1867447, "EndTime": 1628187834.6029565, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 16740.0, "count": 1, "min": 16740, "max": 16740}, "Total Batches Seen": {"sum": 525.0, "count": 1, "min": 525, "max": 525}, "Max Records Seen Between Resets": {"sum": 4177.0, "count": 1, "min": 4177, "max": 4177}, "Max Batches Seen Between Resets": {"sum": 131.0, "count": 1, "min": 131, "max": 131}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 4177.0, "count": 1, "min": 4177, "max": 4177}, "Number of Batches Since Last Reset": {"sum": 131.0, "count": 1, "min": 131, "max": 131}}}
#
# [08/05/2021 18:23:54 INFO 140223054878528] #throughput_metric: host=algo-1, train throughput=1222.6414970882406 records/second
# #metrics {"StartTime": 1628187837.88591, "EndTime": 1628187837.885967, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.6168786306507312, "count": 1, "min": 0.6168786306507312, "max": 0.6168786306507312}}}
#
# #metrics {"StartTime": 1628187837.8860455, "EndTime": 1628187837.886059, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.6180530443214454, "count": 1, "min": 0.6180530443214454, "max": 0.6180530443214454}}}
#
# #metrics {"StartTime": 1628187837.8860936, "EndTime": 1628187837.8861024, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.6218004151319082, "count": 1, "min": 0.6218004151319082, "max": 0.6218004151319082}}}
#
# #metrics {"StartTime": 1628187837.88613, "EndTime": 1628187837.8861384, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.6191093909052702, "count": 1, "min": 0.6191093909052702, "max": 0.6191093909052702}}}
#
# #metrics {"StartTime": 1628187837.8861659, "EndTime": 1628187837.8861737, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.7430264848929186, "count": 1, "min": 0.7430264848929186, "max": 0.7430264848929186}}}
#
# #metrics {"StartTime": 1628187837.8862064, "EndTime": 1628187837.8862154, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.975845187329329, "count": 1, "min": 0.975845187329329, "max": 0.975845187329329}}}
#
# #metrics {"StartTime": 1628187837.886249, "EndTime": 1628187837.886258, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.7459428449662832, "count": 1, "min": 0.7459428449662832, "max": 0.7459428449662832}}}
#
# #metrics {"StartTime": 1628187837.8862994, "EndTime": 1628187837.8863144, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.9853319486746421, "count": 1, "min": 0.9853319486746421, "max": 0.9853319486746421}}}
#
# #metrics {"StartTime": 1628187837.8863547, "EndTime": 1628187837.8863645, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.6088090667930933, "count": 1, "min": 0.6088090667930933, "max": 0.6088090667930933}}}
#
# #metrics {"StartTime": 1628187837.886393, "EndTime": 1628187837.8864012, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.6260066441045358, "count": 1, "min": 0.6260066441045358, "max": 0.6260066441045358}}}
#
# #metrics {"StartTime": 1628187837.8864279, "EndTime": 1628187837.8864355, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.6170929076866462, "count": 1, "min": 0.6170929076866462, "max": 0.6170929076866462}}}
#
# #metrics {"StartTime": 1628187837.8864625, "EndTime": 1628187837.886476, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.618350726366043, "count": 1, "min": 0.618350726366043, "max": 0.618350726366043}}}
#
# #metrics {"StartTime": 1628187837.8865252, "EndTime": 1628187837.8865373, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.7488846836181787, "count": 1, "min": 0.7488846836181787, "max": 0.7488846836181787}}}
#
# #metrics {"StartTime": 1628187837.8865864, "EndTime": 1628187837.886602, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.9831983045889781, "count": 1, "min": 0.9831983045889781, "max": 0.9831983045889781}}}
#
# #metrics {"StartTime": 1628187837.886655, "EndTime": 1628187837.8866658, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.7499582298099995, "count": 1, "min": 0.7499582298099995, "max": 0.7499582298099995}}}
#
# #metrics {"StartTime": 1628187837.8867025, "EndTime": 1628187837.8867183, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.9898088371524444, "count": 1, "min": 0.9898088371524444, "max": 0.9898088371524444}}}
#
# #metrics {"StartTime": 1628187837.8867624, "EndTime": 1628187837.8867722, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.699096953524993, "count": 1, "min": 0.699096953524993, "max": 0.699096953524993}}}
#
# #metrics {"StartTime": 1628187837.8868356, "EndTime": 1628187837.8868508, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.727633435680316, "count": 1, "min": 0.727633435680316, "max": 0.727633435680316}}}
#
# #metrics {"StartTime": 1628187837.8869026, "EndTime": 1628187837.8869126, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.6993828591818992, "count": 1, "min": 0.6993828591818992, "max": 0.6993828591818992}}}
#
# #metrics {"StartTime": 1628187837.8869576, "EndTime": 1628187837.886972, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.7275140427626097, "count": 1, "min": 0.7275140427626097, "max": 0.7275140427626097}}}
#
# #metrics {"StartTime": 1628187837.887019, "EndTime": 1628187837.8870308, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.822122496767686, "count": 1, "min": 0.822122496767686, "max": 0.822122496767686}}}
#
# #metrics {"StartTime": 1628187837.887076, "EndTime": 1628187837.8870873, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 1.0647901673729603, "count": 1, "min": 1.0647901673729603, "max": 1.0647901673729603}}}
#
# ...
#
# [08/05/2021 18:24:31 INFO 140223054878528] #quality_metric: host=algo-1, epoch=13, train mse_objective <loss>=0.5081583276104469
# [08/05/2021 18:24:31 INFO 140223054878528] #early_stopping_criteria_metric: host=algo-1, epoch=13, criteria=mse_objective, value=0.5081583276104469
# [08/05/2021 18:24:31 INFO 140223054878528] Epoch 13: Loss improved. Updating best model
# [08/05/2021 18:24:31 INFO 140223054878528] Saving model for epoch: 13
# [08/05/2021 18:24:31 INFO 140223054878528] Saved checkpoint to "/tmp/tmp957g_gfh/mx-mod-0000.params"
# [08/05/2021 18:24:31 INFO 140223054878528] #progress_metric: host=algo-1, completed 93.33333333333333 % of epochs
# #metrics {"StartTime": 1628187868.7458043, "EndTime": 1628187871.9190214, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 62687.0, "count": 1, "min": 62687, "max": 62687}, "Total Batches Seen": {"sum": 1966.0, "count": 1, "min": 1966, "max": 1966}, "Max Records Seen Between Resets": {"sum": 4177.0, "count": 1, "min": 4177, "max": 4177}, "Max Batches Seen Between Resets": {"sum": 131.0, "count": 1, "min": 131, "max": 131}, "Reset Count": {"sum": 16.0, "count": 1, "min": 16, "max": 16}, "Number of Records Since Last Reset": {"sum": 4177.0, "count": 1, "min": 4177, "max": 4177}, "Number of Batches Since Last Reset": {"sum": 131.0, "count": 1, "min": 131, "max": 131}}}
#
# [08/05/2021 18:24:31 INFO 140223054878528] #throughput_metric: host=algo-1, train throughput=1316.2855369738759 records/second
# #metrics {"StartTime": 1628187875.1389976, "EndTime": 1628187875.139054, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.5049522950672186, "count": 1, "min": 0.5049522950672186, "max": 0.5049522950672186}}}
#
# #metrics {"StartTime": 1628187875.1391325, "EndTime": 1628187875.1391454, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.5272596850991249, "count": 1, "min": 0.5272596850991249, "max": 0.5272596850991249}}}
#
# #metrics {"StartTime": 1628187875.1391797, "EndTime": 1628187875.1391883, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.5060801115746681, "count": 1, "min": 0.5060801115746681, "max": 0.5060801115746681}}}
#
# #metrics {"StartTime": 1628187875.139216, "EndTime": 1628187875.1392238, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.5281694063773522, "count": 1, "min": 0.5281694063773522, "max": 0.5281694063773522}}}
#
# #metrics {"StartTime": 1628187875.1392572, "EndTime": 1628187875.139266, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.6009375082185635, "count": 1, "min": 0.6009375082185635, "max": 0.6009375082185635}}}
#
# #metrics {"StartTime": 1628187875.1392937, "EndTime": 1628187875.1393063, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.8775278028960412, "count": 1, "min": 0.8775278028960412, "max": 0.8775278028960412}}}
#
# #metrics {"StartTime": 1628187875.1393628, "EndTime": 1628187875.139374, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.6022818881158646, "count": 1, "min": 0.6022818881158646, "max": 0.6022818881158646}}}
#
# #metrics {"StartTime": 1628187875.139404, "EndTime": 1628187875.139412, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.8775080198278794, "count": 1, "min": 0.8775080198278794, "max": 0.8775080198278794}}}
#
# #metrics {"StartTime": 1628187875.139439, "EndTime": 1628187875.1394467, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.5063643662115702, "count": 1, "min": 0.5063643662115702, "max": 0.5063643662115702}}}
#
# #metrics {"StartTime": 1628187875.1394746, "EndTime": 1628187875.139482, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.5319390974365747, "count": 1, "min": 0.5319390974365747, "max": 0.5319390974365747}}}
#
# #metrics {"StartTime": 1628187875.1395147, "EndTime": 1628187875.1395285, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.5091646019369364, "count": 1, "min": 0.5091646019369364, "max": 0.5091646019369364}}}
#
# #metrics {"StartTime": 1628187875.1395848, "EndTime": 1628187875.1396017, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.5320569424675061, "count": 1, "min": 0.5320569424675061, "max": 0.5320569424675061}}}
#
# #metrics {"StartTime": 1628187875.1396604, "EndTime": 1628187875.139676, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.6102005976323898, "count": 1, "min": 0.6102005976323898, "max": 0.6102005976323898}}}
#
# #metrics {"StartTime": 1628187875.1397388, "EndTime": 1628187875.139756, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.880500814375969, "count": 1, "min": 0.880500814375969, "max": 0.880500814375969}}}
#
# #metrics {"StartTime": 1628187875.1398163, "EndTime": 1628187875.139833, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.610218868805812, "count": 1, "min": 0.610218868805812, "max": 0.610218868805812}}}
#
# #metrics {"StartTime": 1628187875.1398847, "EndTime": 1628187875.139901, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.8805011869049989, "count": 1, "min": 0.8805011869049989, "max": 0.8805011869049989}}}
#
# #metrics {"StartTime": 1628187875.139961, "EndTime": 1628187875.139978, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.6447016176696007, "count": 1, "min": 0.6447016176696007, "max": 0.6447016176696007}}}
#
# #metrics {"StartTime": 1628187875.1400259, "EndTime": 1628187875.1400359, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.7176205590940439, "count": 1, "min": 0.7176205590940439, "max": 0.7176205590940439}}}
#
# #metrics {"StartTime": 1628187875.1400812, "EndTime": 1628187875.1400962, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.6447021656311476, "count": 1, "min": 0.6447021656311476, "max": 0.6447021656311476}}}
#
# #metrics {"StartTime": 1628187875.1401548, "EndTime": 1628187875.1401713, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.7176042410043569, "count": 1, "min": 0.7176042410043569, "max": 0.7176042410043569}}}
#
# #metrics {"StartTime": 1628187875.1402276, "EndTime": 1628187875.1402438, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.8229262556594151, "count": 1, "min": 0.8229262556594151, "max": 0.8229262556594151}}}
#
# #metrics {"StartTime": 1628187875.1403039, "EndTime": 1628187875.14032, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.9339445374332942, "count": 1, "min": 0.9339445374332942, "max": 0.9339445374332942}}}
#
# #metrics {"StartTime": 1628187875.1403685, "EndTime": 1628187875.1403818, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.8229304714271656, "count": 1, "min": 0.8229304714271656, "max": 0.8229304714271656}}}
#
# #metrics {"StartTime": 1628187875.1404393, "EndTime": 1628187875.1404555, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.9339337069827777, "count": 1, "min": 0.9339337069827777, "max": 0.9339337069827777}}}
#
# #metrics {"StartTime": 1628187875.1405063, "EndTime": 1628187875.1405213, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.9719945097771975, "count": 1, "min": 0.9719945097771975, "max": 0.9719945097771975}}}
#
# #metrics {"StartTime": 1628187875.1405728, "EndTime": 1628187875.1405885, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 1.0217386517960292, "count": 1, "min": 1.0217386517960292, "max": 1.0217386517960292}}}
#
# #metrics {"StartTime": 1628187875.1406465, "EndTime": 1628187875.1406565, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 0.9720265940404855, "count": 1, "min": 0.9720265940404855, "max": 0.9720265940404855}}}
#
# #metrics {"StartTime": 1628187875.1407006, "EndTime": 1628187875.1407158, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 1.021765866015966, "count": 1, "min": 1.021765866015966, "max": 1.021765866015966}}}
#
# #metrics {"StartTime": 1628187875.1407728, "EndTime": 1628187875.1407886, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.084587069715445, "count": 1, "min": 1.084587069715445, "max": 1.084587069715445}}}
#
# #metrics {"StartTime": 1628187875.1408494, "EndTime": 1628187875.1408653, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.1515506354662088, "count": 1, "min": 1.1515506354662088, "max": 1.1515506354662088}}}
#
# #metrics {"StartTime": 1628187875.1409178, "EndTime": 1628187875.140928, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.0845785034963717, "count": 1, "min": 1.0845785034963717, "max": 1.0845785034963717}}}
#
# #metrics {"StartTime": 1628187875.1409605, "EndTime": 1628187875.140973, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.1514988076228363, "count": 1, "min": 1.1514988076228363, "max": 1.1514988076228363}}}
#
# [08/05/2021 18:24:35 INFO 140223054878528] #quality_metric: host=algo-1, epoch=14, train mse_objective <loss>=0.5049522950672186
# [08/05/2021 18:24:35 INFO 140223054878528] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=mse_objective, value=0.5049522950672186
# [08/05/2021 18:24:35 INFO 140223054878528] Epoch 14: Loss improved. Updating best model
# [08/05/2021 18:24:35 INFO 140223054878528] Saving model for epoch: 14
# [08/05/2021 18:24:35 INFO 140223054878528] Saved checkpoint to "/tmp/tmplj2qm3n7/mx-mod-0000.params"
# [08/05/2021 18:24:35 INFO 140223054878528] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1628187871.9192462, "EndTime": 1628187875.1505294, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 66864.0, "count": 1, "min": 66864, "max": 66864}, "Total Batches Seen": {"sum": 2097.0, "count": 1, "min": 2097, "max": 2097}, "Max Records Seen Between Resets": {"sum": 4177.0, "count": 1, "min": 4177, "max": 4177}, "Max Batches Seen Between Resets": {"sum": 131.0, "count": 1, "min": 131, "max": 131}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 4177.0, "count": 1, "min": 4177, "max": 4177}, "Number of Batches Since Last Reset": {"sum": 131.0, "count": 1, "min": 131, "max": 131}}}
#
# [08/05/2021 18:24:35 INFO 140223054878528] #throughput_metric: host=algo-1, train throughput=1292.6167507697955 records/second
# [08/05/2021 18:24:35 WARNING 140223054878528] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [08/05/2021 18:24:35 WARNING 140223054878528] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [08/05/2021 18:24:35 INFO 140223054878528] #train_score (algo-1) : ('mse_objective', 5.1011368160416755)
# [08/05/2021 18:24:35 INFO 140223054878528] #train_score (algo-1) : ('mse', 5.1011368160416755)
# [08/05/2021 18:24:35 INFO 140223054878528] #train_score (algo-1) : ('absolute_loss', 1.5949838787624075)
# [08/05/2021 18:24:35 INFO 140223054878528] #quality_metric: host=algo-1, train mse_objective <loss>=5.1011368160416755
# [08/05/2021 18:24:35 INFO 140223054878528] #quality_metric: host=algo-1, train mse <loss>=5.1011368160416755
# [08/05/2021 18:24:35 INFO 140223054878528] #quality_metric: host=algo-1, train absolute_loss <loss>=1.5949838787624075
# [08/05/2021 18:24:35 INFO 140223054878528] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.005, "l1": 0.0, "wd": 0.0001, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [08/05/2021 18:24:35 INFO 140223054878528] Saved checkpoint to "/tmp/tmp0afs4rsl/mx-mod-0000.params"
# [08/05/2021 18:24:35 INFO 140223054878528] Test data is not provided.
# #metrics {"StartTime": 1628187822.6059172, "EndTime": 1628187875.8021946, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 1546.38671875, "count": 1, "min": 1546.38671875, "max": 1546.38671875}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 16.00933074951172, "count": 15, "min": 0.9312629699707031, "max": 1.3427734375}, "update.time": {"sum": 50945.688247680664, "count": 15, "min": 3096.8055725097656, "max": 3765.8188343048096}, "finalize.time": {"sum": 645.9567546844482, "count": 1, "min": 645.9567546844482, "max": 645.9567546844482}, "setuptime": {"sum": 25.25925636291504, "count": 1, "min": 25.25925636291504, "max": 25.25925636291504}, "totaltime": {"sum": 53442.223072052, "count": 1, "min": 53442.223072052, "max": 53442.223072052}}}
#
#
# 2021-08-05 18:24:53 Uploading - Uploading generated training model
# 2021-08-05 18:24:53 Completed - Training job completed
# Training seconds: 171
# Billable seconds: 171

# %% [markdown]
# ## CREATE PIPELINE

# %% [markdown]
# ### Setup pipeline

# %%
from sagemaker.model import Model
from sagemaker.pipeline import PipelineModel
import boto3
from time import gmtime, strftime

timestamp_prefix = strftime("%Y-%m-%d-%H-%M-%S", gmtime())

scikit_learn_inferencee_model = sklearn_preprocessor.create_model()
linear_learner_model = ll_estimator.create_model()

model_name = "inference-pipeline-" + timestamp_prefix
endpoint_name = "inference-pipeline-ep-" + timestamp_prefix
sm_model = PipelineModel(
    name=model_name, role=role, models=[scikit_learn_inferencee_model, linear_learner_model]
)

sm_model.deploy(initial_instance_count=1, instance_type="ml.c4.xlarge", endpoint_name=endpoint_name)
# Out:
# -----------------!

# %%
model_name
# Out:
# 'inference-pipeline-2021-08-05-19-04-05'

# %%
endpoint_name
# Out:
# 'inference-pipeline-ep-2021-08-05-19-04-05'

# %% [markdown]
# ## MAKE REQUEST

# %%
from sagemaker.predictor import Predictor
from sagemaker.serializers import CSVSerializer

payload = "M, 0.44, 0.365, 0.125, 0.516, 0.2155, 0.114, 0.155"
actual_rings = 10
predictor = Predictor(
    endpoint_name=endpoint_name, sagemaker_session=sagemaker_session, serializer=CSVSerializer()
)

print(predictor.predict(payload))
# Out:
# b'{"predictions": [{"score": 9.528051376342773}]}'
